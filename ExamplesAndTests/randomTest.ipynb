# %% [markdown]
# **Test random function**

# %% [markdown]
# Import random from local directory

# %%
cd ..
# Out:
# /home/florian/Projects/Own_Library/Own_Library

# %%
from packageFlo.randomMatrix import randomMatrix

# %%
help(randomMatrix)
# Out:
# Help on function randomMatrix in module packageFlo.randomMatrix:
#
# randomMatrix(m, n)
#     Pseudo random number generator.
#
#     This function returns a matrix (list in list) consisting of numbers(between -0.5 and 0.5) generated by
#     the linear congruential generator (LCG) algorithm. This function always returns
#     the same matrix for the same input.
#
#     P.S. Since matrices and arrays are not built in Python functions we are using lists.
#     Lists are of the form [x,y,z]. And we identify lists in a list as matrices, i.e.,
#     [[2,4],[4,4],[2,2]] would be an example of a 3x2 matrix.
#
#
#     Parameters:
#     -----------
#     m: int which is >0
#         Number of rows of the pseudo random matrix.
#     n: int which is >0
#         Number of columns of the pseudo random matrix.
#
#     Returns:
#     --------
#     list of legnth m where each element is a list containing n float numbers
# ...

# %% [markdown]
# Some basic examples

# %%
randomMatrix(1,4)
# Out:
# [[-0.494293299967957,
#   -0.0708683644353571,
#   -0.3139981994903642,
#   0.4512641713841037]]

# %%
randomMatrix(1,5)
# Out:
# [[-0.494293299967957,
#   -0.0708683644353571,
#   -0.3139981994903642,
#   0.4512641713841037,
#   -0.15405801303080702]]

# %%
randomMatrix(4,1)
# Out:
# [[-0.494293299967957],
#  [-0.0708683644353571],
#  [-0.3139981994903642],
#  [0.4512641713841037]]

# %%
randomMatrix(1,20)
# Out:
# [[-0.494293299967957,
#   -0.0708683644353571,
#   -0.3139981994903642,
#   0.4512641713841037,
#   -0.15405801303080702,
#   0.4467781558508934,
#   -0.4905091780215756,
#   0.21294078154325036,
#   -0.0283122510948014,
#   -0.12228969894868547,
#   -0.17059828798999038,
#   0.2062575339121412,
#   0.47044417657201276,
#   0.284442376062377,
#   0.3343073378396936,
#   0.07417947113844092,
#   -0.43541053145551367,
#   0.3453392739978943,
#   -0.09842531699650581,
#   -0.38076964157651405]]

# %% [markdown]
# See if average goes to 0 and print max and min number

# %%
r = randomMatrix(1,1000000)
s = 0

for i in range(1000000):
    s += r[0][i]
    
print(s/1000000)
print(min(r[0]))
print(max(r[0]))
# Out:
# 1.4109709019336769e-05
# -0.5
# 0.4999694828875292

# %% [markdown]
# Some wrong input types

# %%
randomMatrix(1)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_6355/3786646979.py in <module>
# ----> 1 randomMatrix(1)
#
# TypeError: randomMatrix() missing 1 required positional argument: 'n'

# %%
randomMatrix(1,2,3)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_6355/3475837145.py in <module>
# ----> 1 randomMatrix(1,2,3)
#
# TypeError: randomMatrix() takes 2 positional arguments but 3 were given

# %%
randomMatrix(1,2j)
# Out:
# TypeError: random() needs 2 positive integers
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~/Projects/Own_Library/Own_Library/packageFlo/randomMatrix.py in randomMatrix(m, n)
#      38         if (isinstance(m, int) == 0) or (isinstance(n, int) == 0):
# ---> 39             raise TypeError('TypeError: random() needs 2 positive integers')
#      40
#
# TypeError: TypeError: random() needs 2 positive integers
#
# During handling of the above exception, another exception occurred:
#
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_6355/700710848.py in <module>
# ----> 1 randomMatrix(1,2j)
#
# ~/Projects/Own_Library/Own_Library/packageFlo/randomMatrix.py in randomMatrix(m, n)
#      51     except TypeError as te: #this is executed for all TypeErrors in the try block above
# ...

# %%
randomMatrix(1,1.5)
# Out:
# TypeError: random() needs 2 positive integers
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~/Projects/Own_Library/Own_Library/packageFlo/randomMatrix.py in randomMatrix(m, n)
#      38         if (isinstance(m, int) == 0) or (isinstance(n, int) == 0):
# ---> 39             raise TypeError('TypeError: random() needs 2 positive integers')
#      40
#
# TypeError: TypeError: random() needs 2 positive integers
#
# During handling of the above exception, another exception occurred:
#
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_6355/3929326152.py in <module>
# ----> 1 randomMatrix(1,1.5)
#
# ~/Projects/Own_Library/Own_Library/packageFlo/randomMatrix.py in randomMatrix(m, n)
#      51     except TypeError as te: #this is executed for all TypeErrors in the try block above
# ...
